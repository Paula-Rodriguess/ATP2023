# %%
from random import randint

Menu=("Menu|nEscolha a opção:\n(1)Criar Lista\n(2)Ler Lista\n(3)Soma\(4)Média\(5)Maior\(6)Menor\(7)Lista ordenada por ordem crescente\(8)Lista ordenada por ordem decrescente\(9)Procurar um elemento")

lista=[]
print(Menu)
programa=True
while programa==True:
    N=int(input("Menu|nEscolha a opção:\n(1)Criar Lista\n(2)Ler Lista\n(3)Soma\(4)Média\(5)Maior\(6)Menor\(7)Lista ordenada por ordem crescente\(8)Lista ordenada por ordem decrescente\(9)Procurar um elemento"))
    if N==0:
        print(lista)
        print("Out")
        programa=False
    if N==1:
        lista.clear()
        print("Qual o tamanho de lista pretendido?")
        n=int(input("Escolha o tamanho da lista"))
        while n>0:
            lista.append(randint(1,101))
        print(lista)
        print(Menu)
    if N==2:
        lista.clear()
        print("Escolha o tamanho da lista")
        while tamanho>0:
            x=int(input("Escolha o tamanho da lista"))
            lista.append(x)
            tamanho=tamanho-1
        print(lista)
        print(Menu)
    if N==3:
        soma=0
        for i in lista:
            soma=soma+i
        print(soma)
        print(Menu)
    if N==4:
        soma1=0
        divisor=len(lista)
        for i in lista:
            soma1=soma1+i
        print(soma1/divisor)
        print(Menu)
    if N==5:
        maior=lista[0]
        for i in lista:
            if i > maior:
                maior=i
        print(maior)
        print(Menu)
    if N==6:
        menor=lista[0]
        for i in lista:
            if i < menor:
                menor=i
        print(menor)
        print(Menu)
    if N==7:
        listacopiada=[]
        for i in lista:
            listacopiada.append(i)
        listacopiada.sort()
        if lista==listacopiada:
            print("Sim")
        else:
            print("Não")
        print(Menu)
    if N==8:
        for i in lista:
            listacopiada.append(i)
        listacopiada.sort(reverse=True)
        if lista==listacopiada:
            print("Sim")
        else:
            print("Não")
        print(Menu)
    if N==9:
        print(Menu)
# Out:
# Failed to interrupt the Kernel.
#
# No kernel associated with the notebook.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
